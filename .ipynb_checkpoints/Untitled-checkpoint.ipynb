# %%
t = """<html>
 <head>
  <meta content="text/html;charset=utf-8" http-equiv="Content-Type"/>
  <meta content="utf-8" http-equiv="encoding"/>
 </head>
 <body>
  <table>
   <tr id="row_0">
    <td>
     Mike Lake (Edmonton--Wetaskiwin)
    </td>
    <td>
     Damien Kurek (Battle River--Crowfoot)
    </td>
    <td>
     John Barlow (Foothills)
    </td>
    <td>
     Tom Kmiec (Calgary Shepard)
    </td>
    <td>
     Earl Dreeshen (Red Deer--Mountain View)
    </td>
    <td>
     Blaine Calkins (Red Deer--Lacombe)
    </td>
    <td>
     Blake Richards (Banff--Airdrie)
    </td>
    <td>
     Chris Warkentin (Grande Prairie--Mackenzie)
    </td>
    <td>
     Dane Lloyd (Sturgeon River--Parkland)
    </td>
    <td>
     Garnett Genuis (Sherwood Park--Fort Saskatchewan)
    </td>
   </tr>
   <tr id="row_1">
   </tr>
   <tr id="row_2">
   </tr>
   <tr id="row_3">
   </tr>
   <tr id="row_4">
   </tr>
   <tr id="row_5">
   </tr>
   <tr id="row_6">
   </tr>
   <tr id="row_7">
   </tr>
   <tr id="row_8">
   </tr>
   <tr id="row_9">
   </tr>
   <tr id="row_10">
   </tr>
   <tr id="row_11">
   </tr>
   <tr id="row_12">
   </tr>
   <tr id="row_13">
   </tr>
   <tr id="row_14">
   </tr>
   <tr id="row_15">
   </tr>
   <tr id="row_16">
   </tr>
   <tr id="row_17">
   </tr>
   <tr id="row_18">
   </tr>
   <tr id="row_19">
   </tr>
   <tr id="row_20">
   </tr>
   <tr id="row_21">
   </tr>
   <tr id="row_22">
   </tr>
   <tr id="row_23">
   </tr>
   <tr id="row_24">
   </tr>
   <tr id="row_25">
   </tr>
   <tr id="row_26">
   </tr>
   <tr id="row_27">
   </tr>
   <tr id="row_28">
   </tr>
   <tr id="row_29">
   </tr>
   <tr id="row_30">
   </tr>
   <tr id="row_31">
   </tr>
   <tr id="row_32">
   </tr>
   <tr id="row_33">
   </tr>
   <tr id="row_34">
   </tr>
   <tr id="row_35">
   </tr>
   <tr id="row_36">
   </tr>
   <tr id="row_37">
   </tr>
   <tr id="row_38">
   </tr>
   <tr id="row_39">
   </tr>
   <tr id="row_40">
   </tr>
   <tr id="row_41">
   </tr>
   <tr id="row_42">
   </tr>
   <tr id="row_43">
   </tr>
   <tr id="row_44">
   </tr>
   <tr id="row_45">
   </tr>
   <tr id="row_46">
   </tr>
   <tr id="row_47">
   </tr>
   <tr id="row_48">
   </tr>
   <tr id="row_49">
   </tr>
   <tr id="row_50">
   </tr>
   <tr id="row_51">
   </tr>
   <tr id="row_52">
   </tr>
   <tr id="row_53">
   </tr>
   <tr id="row_54">
   </tr>
   <tr id="row_55">
   </tr>
   <tr id="row_56">
   </tr>
   <tr id="row_57">
   </tr>
   <tr id="row_58">
   </tr>
   <tr id="row_59">
   </tr>
   <tr id="row_60">
   </tr>
   <tr id="row_61">
   </tr>
   <tr id="row_62">
   </tr>
   <tr id="row_63">
   </tr>
   <tr id="row_64">
   </tr>
   <tr id="row_65">
   </tr>
   <tr id="row_66">
   </tr>
   <tr id="row_67">
   </tr>
   <tr id="row_68">
   </tr>
   <tr id="row_69">
   </tr>
   <tr id="row_70">
   </tr>
   <tr id="row_71">
   </tr>
   <tr id="row_72">
   </tr>
   <tr id="row_73">
   </tr>
   <tr id="row_74">
   </tr>
   <tr id="row_75">
   </tr>
   <tr id="row_76">
   </tr>
   <tr id="row_77">
   </tr>
   <tr id="row_78">
   </tr>
   <tr id="row_79">
   </tr>
   <tr id="row_80">
   </tr>
   <tr id="row_81">
   </tr>
   <tr id="row_82">
   </tr>
   <tr id="row_83">
   </tr>
   <tr id="row_84">
   </tr>
   <tr id="row_85">
   </tr>
   <tr id="row_86">
   </tr>
   <tr id="row_87">
   </tr>
   <tr id="row_88">
   </tr>
   <tr id="row_89">
   </tr>
   <tr id="row_90">
   </tr>
   <tr id="row_91">
   </tr>
   <tr id="row_92">
   </tr>
  </table>
  <p class="overview">
   Test
  </p>
 </body>
</html>"""

# %%
from bs4 import BeautifulSoup, NavigableString
doc = BeautifulSoup(t, 'html.parser')
doc.find(id='row_2')
# Out:
# <tr id="row_2">
# </tr>

# %%
from bs4 import BeautifulSoup, NavigableString
doc = BeautifulSoup('<body><table></table></body>', 'html.parser')
for row_count in range(10):
  row = doc.new_tag('tr', id=f'row_{row_count}')
  cell = doc.new_tag('td',class_=party)
  cell.contents.append(NavigableString('hi'))
  doc.find(id=row_id).append(cell)
#   doc.find('table').append(row)
  
# for row_count in range(10):
#   row = doc.find(id=f'row_{row_count}')
#   cell = doc.new_tag('td',class_='test')
# #   cell.contents.append(NavigableString('hi'))
#   row.append(cell)
#   print(row)

print(doc.prettify())
# Out:
# <body>
#  <table>
#  </table>
# </body>

# %%
from math import ceil
import traceback
template = """
<html>
  <head>
    <meta content="text/html;charset=utf-8" http-equiv="Content-Type">
    <meta content="utf-8" http-equiv="encoding">
  </head>

  <body>
    <table>
    </table>
    <p class="overview">
      Test
    </p>
  </body>
</html>
"""
doc = BeautifulSoup(template, 'html.parser')
party_names = ['Liberal', 'Conservative']
seats_in_unrep_parliament = 20
party_winners = {'Liberal': [
  [
    "Chris Rodgers (Carleton)",
    26518
  ],
  [
    "Francis Scarpaleggia (Lac-Saint-Louis)",
    25538
  ],
  [
    "Kim Rudd (Northumberland--Peterborough South/Northumberland--Peterborough-Sud)",
    24977
  ],
  [
    "Lorne Kenney (Simcoe--Grey)",
    23925
  ],
  [
    "Jonathan Giancroce (Durham)",
    23547
  ],
  [
    "Jennifer Stebbing (Flamborough--Glanbrook)",
    22875
  ],
  [
    "Andrea Kaiser (Niagara Falls)",
    22690
  ],
  [
    "Michele Fisher (Dufferin--Caledon)",
    22645
  ],
  [
    "Stephen Fuhr (Kelowna--Lake Country)",
    22627
  ]], 
'Conservative':
[[
    "Mike Lake (Edmonton--Wetaskiwin)",
    52543
  ],
  [
    "Damien Kurek (Battle River--Crowfoot)",
    50123
  ],
  [
    "John Barlow (Foothills)",
    50015
  ],
  [
    "Tom Kmiec (Calgary Shepard)",
    49969
  ],
  [
    "Earl Dreeshen (Red Deer--Mountain View)",
    49818
  ],
  [
    "Blaine Calkins (Red Deer--Lacombe)",
    47830
  ],
  [
    "Blake Richards (Banff--Airdrie)",
    47078
  ],
  [
    "Chris Warkentin (Grande Prairie--Mackenzie)",
    46952
  ],
  [
    "Dane Lloyd (Sturgeon River--Parkland)",
    46294
  ],
  [
    "Garnett Genuis (Sherwood Park--Fort Saskatchewan)",
    44732
  ],
  [
    "Shannon Stubbs (Lakeland)",
    44585
  ]]}

for row_count in range(ceil(seats_in_unrep_parliament/10)):
  row = doc.new_tag('tr', id=f'row_{row_count}')
  doc.find('table').append(row)

seat_count = 0
for party in party_names:
  if exit:
    break
  for winner in party_winners[party]:
    row_id = f'row_{seat_count//10}'
    seat_count += 1
    cell = doc.new_tag('td',class_=party)
    cell.contents.append(NavigableString(winner[0]))
    try:
      doc.find(id=row_id).append(cell)
    except AttributeError:
      print(traceback.format_exc())
      print(doc.prettify())
      exit = True
      break
# Out:
# Traceback (most recent call last):
#   File "<ipython-input-13-986e90f479ff>", line 117, in <module>
#     doc.find(id=row_id).append(cell)
# AttributeError: 'NoneType' object has no attribute 'append'
#
# Traceback (most recent call last):
#   File "<ipython-input-13-986e90f479ff>", line 117, in <module>
#     doc.find(id=row_id).append(cell)
# AttributeError: 'NoneType' object has no attribute 'append'
#
# Traceback (most recent call last):
#   File "<ipython-input-13-986e90f479ff>", line 117, in <module>
#     doc.find(id=row_id).append(cell)
# AttributeError: 'NoneType' object has no attribute 'append'
#
# Traceback (most recent call last):
#   File "<ipython-input-13-986e90f479ff>", line 117, in <module>
#     doc.find(id=row_id).append(cell)
# AttributeError: 'NoneType' object has no attribute 'append'
#
# Traceback (most recent call last):
#   File "<ipython-input-13-986e90f479ff>", line 117, in <module>
#     doc.find(id=row_id).append(cell)
# ...
